# %%
from multi_level_protocol import *

# %%
# Optimal infidelity
for l in range(4, 30):
    print(l,optimized_infidelity_level_one(beta=np.pi/2**l, p_phy=0.001))
# l, d, output_infidelity, spacetime_overhead
# Out:
# 4 (45, np.float64(0.00010203905901934933))
# 5 (45, np.float64(3.55369424233049e-05))
# 6 (45, np.float64(1.1324875605121819e-05))
# 7 (45, np.float64(3.5342792894052124e-06))
# 8 (45, np.float64(1.0696235326868532e-06))
# 9 (45, np.float64(3.268490342632942e-07))
# 10 (45, np.float64(9.677097767040218e-08))
# 11 (45, np.float64(2.7905547607085897e-08))
# 12 (45, np.float64(8.104928794781434e-09))
# 13 (45, np.float64(2.3193012940048133e-09))
# 14 (45, np.float64(6.558805434705209e-10))
# 15 (45, np.float64(1.844399684065669e-10))
# 16 (45, np.float64(5.2055142039877336e-11))
# 17 (45, np.float64(1.4490937622023758e-11))
# 18 (45, np.float64(3.992091392136674e-12))
# 19 (45, np.float64(1.1034847540959992e-12))
# 20 (45, np.float64(3.049335197338169e-13))
# 21 (45, np.float64(8.355135087607053e-14))
# 22 (45, np.float64(2.274844304258595e-14))
# 23 (45, np.float64(6.203948817503718e-15))
# 24 (45, np.float64(1.6827676470579361e-15))
# 25 (45, np.float64(4.54509775192288e-16))
# ...

# %%
for l in range(4, 30):
    print(l,optimized_infidelity_level_two(gamma=np.pi/2**l, p_phy=0.001))

# %%
for l in range(4, 30):
    print(l,optimized_infidelity_level_three(delta=np.pi/2**l, p_phy=0.001))

# %%
for l in range(4, 30):
    print(l,optimized_infidelity_level_four(theta=np.pi/2**l, p_phy=0.001))

# %%
# optimizing spacetime_volume for target_error_rate

for l in range(18, 26):
    print(l,optimized_spacetime_volume_level_one(target_error_rate = 10**(-12), beta=np.pi/2**l, p_phy=0.001))
#[dx, dz, output_infidelity, spacetime_overhead]
# Out:
# 18 (3, 4, 1, inf)
# 19 (3, 4, 1, inf)
# 20 (3, 21, np.float64(9.011942767223602e-13), np.float64(450.09190502790574))
# 21 (3, 21, np.float64(3.595757652445543e-13), np.float64(435.7281899517962))
# 22 (3, 21, np.float64(2.0538852405614724e-13), np.float64(424.2384741091717))
# 23 (3, 21, np.float64(1.610692004468024e-13), np.float64(415.0080053872859))
# 24 (3, 21, np.float64(1.4820636675861885e-13), np.float64(407.5621027473923))
# 25 (3, 21, np.float64(1.4444504695872927e-13), np.float64(401.5505286475858))

# %%
for l in range(12, 26):
    print(l,optimized_spacetime_volume_level_two(target_error_rate = 10**(-12), gamma=np.pi/2**l, p_phy=0.001))
#[k2,dz2,dx2,dz1,dx1, t_error, t_volume, output_infidelity, spacetime_overhead]
# Out:
# 12 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 13 [9, 21, 7, 15, 17, 1e-08, 40000, np.float64(9.797008504238586e-13), np.float64(3869786.670540241)]
# 14 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 15 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 16 [11, 15, 5, 11, 13, 3e-06, 8000, np.float64(9.160950311431045e-13), np.float64(1813976.672129315)]
# 17 [11, 15, 6, 9, 11, 5e-06, 6000, np.float64(9.54504777004066e-13), np.float64(1418085.3686930744)]
# 18 [10, 12, 7, 9, 11, 7e-06, 5000, np.float64(6.789675286503419e-13), np.float64(540425.7840501633)]
# 19 [8, 12, 7, 7, 9, 7e-06, 5000, np.float64(8.249347297405908e-13), np.float64(230260.0251563355)]
# 20 [8, 9, 5, 7, 8, 8e-05, 4000, np.float64(7.339665913555999e-13), np.float64(116677.49984958158)]
# 21 [9, 9, 5, 5, 7, 0.0004, 1000, np.float64(3.3787007066410547e-13), np.float64(97746.17715216655)]
# 22 [29, 30, 1, 4, 5, 0.0004, 1000, np.float64(5.610220569080678e-13), np.float64(18397.515654556515)]
# ...

# %%
for l in range(7, 26):
    print(l,optimized_spacetime_volume_level_three(target_error_rate = 10**(-12), delta=np.pi/2**l, p_phy=0.001))
#[k3,dz3,dx3,k2,dz2,dx2,dz1,dx1, t_error, t_volume, output_infidelity, spacetime_overhead]
# Out:
# 7 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 8 [5, 21, 21, 8, 15, 7, 23, 12, 3e-06, 8000, 1.2955e-12, 4685822, np.float64(9.521682512471591e-13), np.float64(64589897.611487426)]
# 9 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 10 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 11 [14, 19, 20, 2, 21, 9, 22, 19, 1e-09, 100000, 1e-09, 100000, np.float64(9.85446080531832e-13), np.float64(1008720277.4826454)]
# 12 [8, 17, 17, 6, 15, 4, 19, 11, 7e-06, 5000, 6e-09, 50000, np.float64(9.437039786905006e-13), np.float64(16673076.874129722)]
# 13 [9, 15, 16, 4, 12, 7, 18, 9, 5e-06, 6000, 1e-08, 40000, np.float64(9.679713627988343e-13), np.float64(8079827.903495316)]
# 14 [8, 14, 15, 3, 15, 7, 17, 13, 2e-07, 20000, 3e-08, 30000, np.float64(8.516027278999168e-13), np.float64(6001279.822218574)]
# 15 [6, 15, 15, 2, 15, 7, 17, 15, 3e-08, 30000, 3e-08, 30000, np.float64(9.090975691632569e-13), np.float64(1924738.943580088)]
# ...

# %%
for l in [8]:
    print(l,optimized_spacetime_volume_level_four(target_error_rate = 10**(-12), theta=np.pi/2**l, p_phy=0.001))
#[k4,dz4,dx4,k3,dz3,dx3,k2,dz2,dx2,dz1,dx1, t_error, t_volume, output_infidelity, spacetime_overhead]

# %%
for l in range(12, 26):
    print(l,optimized_spacetime_volume_level_one(target_error_rate = 10**(-9), beta=np.pi/2**l, p_phy=0.001))
# Out:
# 12 (3, 4, 1, inf)
# 13 (3, 4, 1, inf)
# 14 (5, 21, np.float64(7.607066343019781e-10), np.float64(1118.311719379211))
# 15 (3, 15, np.float64(7.334398538285149e-10), np.float64(269.5331380042166))
# 16 (3, 15, np.float64(3.6047815278531757e-10), np.float64(261.7601147361635))
# 17 (3, 15, np.float64(2.491618049893034e-10), np.float64(255.9896277825752))
# 18 (3, 15, np.float64(2.153147897925762e-10), np.float64(251.68448677227283))
# 19 (3, 15, np.float64(2.0484476407396168e-10), np.float64(248.46059758697385))
# 20 (3, 15, np.float64(2.0155451448802767e-10), np.float64(246.0394841080577))
# 21 (3, 15, np.float64(2.0050544832557004e-10), np.float64(244.2171077888034))
# 22 (3, 15, np.float64(2.0016648341640596e-10), np.float64(242.84307987538526))
# 23 (3, 15, np.float64(2.0005558793320376e-10), np.float64(241.80607369212913))
# 24 (3, 15, np.float64(2.0001884093610285e-10), np.float64(241.02273874493235))
# ...

# %%
for l in range(8, 26):
    print(l,optimized_spacetime_volume_level_two(target_error_rate = 10**(-9), gamma=np.pi/2**l, p_phy=0.001))
# Out:
# 8 [5, 18, 3, 12, 15, 3e-08, 30000, np.float64(8.618305747595434e-10), np.float64(688141.620897395)]
# 9 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 10 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 11 [7, 15, 6, 10, 12, 3e-06, 8000, np.float64(9.476138129911794e-10), np.float64(614399.2640894765)]
# 12 [8, 12, 3, 9, 12, 7e-06, 5000, np.float64(5.598888818418609e-10), np.float64(454923.8600211488)]
# 13 [7, 12, 6, 7, 9, 7e-06, 5000, np.float64(8.310066699133646e-10), np.float64(256477.750187821)]
# 14 [7, 9, 5, 7, 9, 7e-06, 5000, np.float64(4.788018763989981e-10), np.float64(144574.0711507647)]
# 15 [6, 9, 5, 7, 9, 0.0004, 1000, np.float64(9.250534707863718e-10), np.float64(59980.80554894674)]
# 16 [7, 9, 4, 5, 6, 0.0004, 1000, np.float64(7.213760036828797e-10), np.float64(67182.06545740183)]
# 17 [26, 30, 1, 4, 5, 0.0004, 1000, np.float64(5.744865910663344e-10), np.float64(7054.793001121484)]
# 18 [28, 30, 1, 4, 1, 0.0004, 1000, np.float64(1.4362164690181091e-10), np.float64(4221.784500022357)]
# ...

# %%
for l in range(4, 26):
    print(l,optimized_spacetime_volume_level_three(target_error_rate = 10**(-9), delta=np.pi/2**l, p_phy=0.001))
# Out:
# 4 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 5 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 6 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 7 [4, 15, 17, 5, 15, 7, 19, 13, 2e-07, 20000, 1e-08, 40000, np.float64(8.744057045076285e-10), np.float64(5202696.003461049)]
# 8 [3, 16, 17, 2, 18, 7, 19, 17, 3e-08, 30000, 6e-09, 50000, np.float64(9.977910173067406e-10), np.float64(1137070.4893610945)]
# 9 [6, 13, 14, 4, 12, 6, 16, 9, 7e-06, 5000, 3e-08, 30000, np.float64(9.36122165288403e-10), np.float64(3235728.7001839234)]
# 10 [4, 13, 13, 2, 15, 5, 15, 13, 2e-07, 20000, 2e-07, 20000, np.float64(8.594856329010168e-10), np.float64(860920.4513324922)]
# 11 [5, 13, 13, 2, 15, 9, 16, 13, 3e-06, 8000, 2e-07, 20000, np.float64(9.732016801132641e-10), np.float64(1147816.8661745342)]
# 12 [5, 11, 11, 2, 12, 4, 13, 11, 7e-06, 5000, 5e-06, 6000, np.float64(9.447564113678328e-10), np.float64(510259.3225733501)]
# ...

# %%
for l in range(21, 26):
    print(l,optimized_spacetime_volume_level_one(target_error_rate = 10**(-15), beta=np.pi/2**l, p_phy=0.001))
# Out:
# 21 (3, 4, 1, inf)
# 22 (3, 4, 1, inf)
# 23 (3, 4, 1, inf)
# 24 (3, 4, 1, inf)
# 25 (5, 27, np.float64(9.016799517460857e-16), np.float64(1154.5005556177828))

# %%
for l in range(17, 26):
    print(l,optimized_spacetime_volume_level_two(target_error_rate = 10**(-15), gamma=np.pi/2**l, p_phy=0.001))
# Out:
# 17 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 18 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 19 [2, 2, 2, 1, 1, 0, 0, 1, inf]
# 20 [14, 18, 9, 13, 16, 2e-07, 20000, np.float64(9.725586544511922e-16), np.float64(7577659.285688435)]
# 21 [15, 15, 5, 12, 15, 3e-06, 8000, np.float64(9.660688424284272e-16), np.float64(4938168.247162892)]
# 22 [14, 15, 9, 11, 13, 3e-06, 8000, np.float64(9.574286100735742e-16), np.float64(3008939.8411023626)]
# 23 [13, 12, 7, 10, 12, 3e-06, 8000, np.float64(7.975334997517501e-16), np.float64(1107340.2833638848)]
# 24 [11, 12, 7, 7, 9, 7e-06, 5000, np.float64(7.742330056051773e-16), np.float64(405570.9837463058)]
# 25 [11, 9, 5, 7, 9, 8e-05, 4000, np.float64(6.791299366514967e-16), np.float64(206336.54677856647)]

# %%
for l in range(15, 26):
    print(l,optimized_spacetime_volume_level_three(target_error_rate = 10**(-15), delta=np.pi/2**l, p_phy=0.001))
# Out:
# 15 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 16 [3, 3, 3, 2, 2, 2, 1, 1, 0, 0, 1, inf]
# 17 [11, 17, 18, 4, 15, 3, 21, 15, 2e-07, 20000, 2e-09, 60000, np.float64(5.620164900066432e-16), np.float64(25495802.293829065)]
# 18 [13, 16, 17, 5, 12, 6, 18, 9, 7e-06, 5000, 6e-09, 50000, np.float64(9.962000397965669e-16), np.float64(30643773.952215116)]
# 19 [8, 15, 15, 2, 18, 7, 18, 15, 3e-08, 30000, 3e-08, 30000, np.float64(9.361190669526414e-16), np.float64(3378806.0198841286)]
# 20 [12, 13, 13, 3, 15, 7, 15, 12, 3e-06, 8000, 3e-08, 30000, np.float64(8.879175412648833e-16), np.float64(10644890.785381664)]
# 21 [9, 13, 13, 2, 15, 3, 15, 13, 3e-06, 8000, 2e-07, 20000, np.float64(8.73594645243519e-16), np.float64(1910274.254798373)]
# 22 [9, 11, 11, 2, 15, 5, 13, 11, 5e-06, 6000, 2e-07, 20000, np.float64(9.080516074511584e-16), np.float64(1611579.4636729136)]
# 23 [10, 9, 10, 2, 12, 3, 12, 11, 7e-06, 5000, 7e-06, 5000, np.float64(5.789638371532066e-16), np.float64(1143132.41982244)]
# ...

# %%
gate_1=[5827026,(5935354.856282866),
 (8319532.407568745),
 (11049669.005112411),
 (13574631.156403974),
 (16226986.134095533),
 (19006383.228704613),
 (21912884.844523806),
 (24062974.64711673), #4
 (9442786.559324792),#4
 (3869786.670540241), #2
 (6001279.822218574) ,#3
 (1924738.943580088) ,#3
 (1497457.4774990478),#2
 (1025946.272820025) ,#3
 (540425.7840501633), #2
 (230260.0251563355) ,#2
 (450.09190502790574) ,#1
 (435.7281899517962) ,#1
 (424.2384741091717) ,#1
 (415.0080053872859) ,#1
 (407.5621027473923), #1
 (401.5505286475858)] #1



gate_5 = [3688250.0, (2809525.7219301634),
 (3747955.3615733115),
 (4705375.713829362),
 (5693789.864059412),
 (4191326.9572888673),#4
 (7296727.071220919),#4
 (4458683.794026304),#3
 (8353632.664172679),#4
 (4354846.089804327),#3
 (1140997.0604834806),#2
 (1699955.1831718434),#2
 (590696.9983209904),#3
 (604676.451499248),#3
 (137156.04112185634),#3
 (125238.3983911754), #2
 (384.1414777020954), #1
 (369.32164388921166), #1
 (212.24941598838438), #1
 (211.05512709782008), #1
 (210.15377406633544), #1
 (209.47290926386844), #1
 (208.95804182638219)] #1

for l in range(4,26):
    print("("+str(sum(gate_1[0:l-2]))+"),")
print("----") 
for l in range(4,26):
    print("("+str(sum(gate_5[0:l-2]))+"),")
# Out:
# (11762380.856282866),
# (20081913.263851613),
# (31131582.268964022),
# (44706213.425367996),
# (60933199.55946353),
# (79939582.78816815),
# (101852467.63269195),
# (125915442.27980869),
# (135358228.83913347),
# (139228015.5096737),
# (145229295.33189228),
# (147154034.27547237),
# (148651491.7529714),
# (149677438.02579144),
# (150217863.8098416),
# (150448123.83499795),
# (150448573.92690298),
# (150449009.65509292),
# (150449433.89356703),
# (150449848.9015724),
# (150450256.46367514),
# (150450658.0142038),
# ----
# (6497775.721930163),
# (10245731.083503474),
# (14951106.797332834),
# (20644896.661392245),
# (24836223.618681114),
# (32132950.689902034),
# (36591634.48392834),
# (44945267.14810102),
# (49300113.237905346),
# (50441110.298388824),
# (52141065.48156067),
# (52731762.47988166),
# (53336438.931380905),
# (53473594.97250276),
# (53598833.37089393),
# (53599217.51237164),
# (53599586.834015526),
# (53599799.08343151),
# (53600010.13855861),
# (53600220.29233268),
# ...

# %%
for l in range(4,26):
    print(l,"("+str(sum([gate_1[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
        
for l in range(4,26):
    print(l,"("+str(sum([gate_5[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
# Out:
# 4 (8848867.856282866)
# 5 (12743966.335710179)
# 6 (17421652.1729675)
# 7 (22285457.242887724)
# 8 (27369714.755539395)
# 9 (32691240.60647431)
# 10 (38258505.14776096)
# 11 (43192227.220997214)
# 12 (31038900.1698234)
# 13 (19389236.75545194)
# 14 (15695898.199944545)
# 15 (9772688.04355236)
# 16 (6383801.499275228)
# 17 (4217847.022457639)
# 18 (2649349.2952789827)
# 19 (1554934.6727958268)
# 20 (777917.4283029413)
# 21 (389394.44234142243)
# 22 (195121.4596448204)
# 23 (97975.73782779748)
# 24 (49395.43101664613)
# 25 (25099.26603697065)
# 4 (4653650.721930163)
# 5 (6074780.722538393)
# 6 (7742766.075098558)
# 7 (9565172.90160869)
# 8 (8973913.408093212)
# 9 (11783683.775267525)
# 10 (10350525.681660067)
# 11 (13528895.505002713)
# 12 (11119293.842305683)
# 13 (6700643.981636322)
# 14 (5050277.173990005)
# 15 (3115835.5853159926)
# 16 (2162594.2441572445)
# 17 (1218453.1632004785)
# 18 (734464.9799914147)
# 19 (367616.6314734094)
# 20 (184177.63738059392)
# 21 (92301.06810628534)
# ...

# %%
#1e-9
gate_1=[100000,
1285910.6893036363,
1980826.2543885268,
2796185.935368079,
3335231.0654790364,
(688141.620897395),
3175813.8995016785,
(860920.4513324922),
(614399.2640894765),
(454923.8600211488),
(256477.750187821),
(1118.311719379211),
(269.5331380042166),
(261.7601147361635),
(255.9896277825752),
(251.68448677227283),
(248.46059758697385),
(246.0394841080577),
(244.2171077888034),
(242.84307987538526),
(241.80607369212913),
(241.02273874493235),
(240.43038356126263)]



gate_5 = [10000,
498900.15626140457,
907058.9396785971,
1052530.0077772124,
1199601.870031218,
294132.3025125971,
503916.3703407338,
(310896.33150088217),
(282951.8592717532),
(112528.94284473949),
(1243.1270491908956),
(243.41352960084652),
(234.25395266309454),
(227.4976610412049),
(222.4819845988753),
(218.73998796422023),
(215.9378124676736),
(213.83340528369664),
(212.24941598838438),
(211.05512709782008),
(210.15377406633544),
(209.47290926386844),
(208.95804182638219)]

for l in range(4,26):
    print("("+str(sum(gate_1[0:l-2]))+"),")
print("----") 
for l in range(4,26):
    print("("+str(sum(gate_5[0:l-2]))+"),")
# Out:
# (1385910.6893036363),
# (3366736.943692163),
# (6162922.879060242),
# (9498153.944539279),
# (10186295.565436674),
# (13362109.464938354),
# (14223029.916270847),
# (14837429.180360323),
# (15292353.040381473),
# (15548830.790569294),
# (15549949.102288673),
# (15550218.635426678),
# (15550480.395541415),
# (15550736.385169197),
# (15550988.06965597),
# (15551236.530253557),
# (15551482.569737665),
# (15551726.786845455),
# (15551969.629925331),
# (15552211.435999023),
# (15552452.458737768),
# (15552692.88912133),
# ----
# (508900.15626140457),
# (1415959.0959400018),
# (2468489.1037172144),
# (3668090.9737484325),
# (3962223.2762610298),
# (4466139.646601764),
# (4777035.978102646),
# (5059987.837374399),
# (5172516.780219139),
# (5173759.9072683295),
# (5174003.3207979305),
# (5174237.574750594),
# (5174465.072411635),
# (5174687.5543962335),
# (5174906.294384197),
# (5175122.232196665),
# (5175336.065601949),
# (5175548.315017937),
# (5175759.370145035),
# (5175969.523919101),
# ...

# %%
for l in range(4,26):
    print(l,"("+str(sum([gate_1[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
        
for l in range(4,26):
    print(l,"("+str(sum([gate_5[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
# Out:
# 4 (1335910.6893036363)
# 5 (2648781.599040345)
# 6 (4120576.734888252)
# 7 (5395519.432923162)
# 8 (3385901.3373589762)
# 9 (4868764.568181166)
# 10 (3295302.7354230755)
# 11 (2262050.6318010143)
# 12 (1585949.175921656)
# 13 (1049452.3381486489)
# 14 (525844.4807937036)
# 15 (263191.773534856)
# 16 (131857.64688216415)
# 17 (66184.81306886465)
# 18 (33344.0910212046)
# 19 (16920.506108189275)
# 20 (8706.292538202695)
# 21 (4597.363376890151)
# 22 (2541.5247683204607)
# 23 (1512.5684578523594)
# 24 (997.306967671112)
# 25 (739.0838673968186)
# 4 (503900.15626140457)
# 5 (1159009.0178092995)
# 6 (1632034.516681862)
# 7 (2015619.128372149)
# 8 (1301941.8666986716)
# 9 (1154887.3036900696)
# 10 (888339.983345917)
# 11 (727121.8509447116)
# 12 (476089.8683170953)
# 13 (239288.06120773853)
# 14 (119887.44413347011)
# 15 (60177.97601939815)
# 16 (30316.48567074028)
# 17 (15380.724819969015)
# 18 (7909.102397948727)
# 19 (4170.489011442037)
# 20 (2299.077911004715)
# 21 (1361.788371490742)
# ...

# %%
#1e-15
gate_1=[ 10272750,
11755124.097771147,
 16132076.40013795,
 21193806.76022114,
 26501240.107829057,
 32340849.032117136,
 38330521.9332965,
 44231078.18245813,
 50824653.04811806,
 57803794.56110604,
 65176550.273501985,
 72957502.40282607,
  62400700.87678659,
  54488683.79989432,
  19514770.60306965,
  18443665.967942175,
 (3378806.0198841286),
  6957017.68486279,
  3414864.8858987074,
 (3008939.8411023626),
 (1107340.2833638848),
 (405570.9837463058),
 (1154.5005556177828)]



gate_5 = [4645822,
5445043.2844123,
7499300.177066407,
9985639.078620192,
11888916.187816449,
14206859.494130194,
16669075.852222418,
19363578.315100454,
24646588.865364715,
28210149.831102435,
23228832.34606631,
29429782.024226792,
9399346.223096823,
8248809.835674121,
2115196.6140522,
5387630.210548975,
(1263836.1674939115),
(1187647.7546787837),
(798182.1484803563),
(585875.1545149629),
(227347.9703633372),
(930.0110972250538),
(329.48668143673996)]

for l in range(4,26):
    print("("+str(sum(gate_1[0:l-2]))+"),")
print("----") 
for l in range(4,26):
    print("("+str(sum(gate_5[0:l-2]))+"),")
# Out:
# (22027874.097771145),
# (38159950.4979091),
# (59353757.25813024),
# (85854997.36595929),
# (118195846.39807642),
# (156526368.33137292),
# (200757446.51383105),
# (251582099.5619491),
# (309385894.12305516),
# (374562444.39655715),
# (447519946.7993832),
# (509920647.6761698),
# (564409331.4760641),
# (583924102.0791337),
# (602367768.0470759),
# (605746574.06696),
# (612703591.7518227),
# (616118456.6377214),
# (619127396.4788238),
# (620234736.7621877),
# (620640307.745934),
# (620641462.2464896),
# ----
# (10090865.2844123),
# (17590165.461478706),
# (27575804.540098898),
# (39464720.72791535),
# (53671580.22204554),
# (70340656.07426795),
# (89704234.38936841),
# (114350823.25473313),
# (142560973.08583558),
# (165789805.43190187),
# (195219587.45612866),
# (204618933.67922547),
# (212867743.51489958),
# (214982940.1289518),
# (220370570.33950076),
# (221634406.50699466),
# (222822054.26167345),
# (223620236.4101538),
# (224206111.56466877),
# (224433459.53503212),
# ...

# %%
for l in range(4,26):
    print(l,"("+str(sum([gate_1[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
        
for l in range(4,26):
    print(l,"("+str(sum([gate_5[i] / 2 ** (l-i-3)  for i in range(0,l-2)]))+")")
# Out:
# 4 (16891499.097771145)
# 5 (24577825.949023522)
# 6 (33482719.7347329)
# 7 (43242599.975195505)
# 8 (53962149.01971489)
# 9 (65311596.44315395)
# 10 (76886876.4040351)
# 11 (89268091.25013562)
# 12 (102437840.18617386)
# 13 (116395470.36658892)
# 14 (131155237.58612053)
# 15 (127978319.66984686)
# 16 (118477843.63481775)
# 17 (78753692.42047852)
# 18 (57820512.17818144)
# 19 (32289062.108974848)
# 20 (23101548.739350215)
# 21 (14965639.255573815)
# 22 (10491759.46888927)
# 23 (6353220.017808519)
# 24 (3582180.9926505657)
# 25 (1792244.9968809006)
# 4 (7767954.2844123)
# 5 (11383277.319272557)
# 6 (15677277.73825647)
# 7 (19727555.056944683)
# 8 (24070637.022602536)
# 9 (28704394.363523684)
# 10 (33715775.49686229)
# 11 (41504476.61379586)
# 12 (48962388.13800037)
# 13 (47710026.415066496)
# 14 (53284795.23176004)
# 15 (36041743.838976845)
# 16 (26269681.755162545)
# 17 (15250037.491633473)
# 18 (13012648.956365712)
# 19 (7770160.645676767)
# 20 (5072728.077517168)
# ...
